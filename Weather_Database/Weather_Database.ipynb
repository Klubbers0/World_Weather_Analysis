# %%
import numpy as np 
from citipy import citipy
import requests
import pandas as pd 
from datetime import datetime

from config import weather_api_key

# %%
# Generate random latitudes and longitudes
lats = np.random.uniform(-90.0,90.0, size=2000)
lngs = np.random.uniform(-180.0,180.0,size=2000)
lats_lngs = zip(lats, lngs)
coordinates = list(lats_lngs)

# Get the nearest city using the citipy module.
cities = list()
for coord in coordinates:
    cities_name = citipy.nearest_city(coord[0],coord[1]).city_name
    if cities_name not in cities:
        cities.append(cities_name)
print(cities[:10], 'Generate', len(cities))
# Out:
# ['oksfjord', 'olot', 'sao filipe', 'hermanus', 'rikitea', 'viedma', 'ushuaia', 'kitimat', 'fuling', 'hamilton'] Generate 775

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=849a98f7615ac315dacfc2b7d048186e

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    


# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description":city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | oksfjord
# Processing Record 2 of Set 1 | olot
# Processing Record 3 of Set 1 | sao filipe
# Processing Record 4 of Set 1 | hermanus
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | viedma
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | kitimat
# Processing Record 9 of Set 1 | fuling
# Processing Record 10 of Set 1 | hamilton
# Processing Record 11 of Set 1 | opuwo
# Processing Record 12 of Set 1 | khankala
# Processing Record 13 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 14 of Set 1 | alugan
# Processing Record 15 of Set 1 | najran
# Processing Record 16 of Set 1 | bluff
# Processing Record 17 of Set 1 | saint-philippe
# Processing Record 18 of Set 1 | bengkulu
# Processing Record 19 of Set 1 | mataura
# Processing Record 20 of Set 1 | ponta do sol
# Processing Record 21 of Set 1 | matara
# Processing Record 22 of Set 1 | longyearbyen
# Processing Record 23 of Set 1 | esperance
# Processing Record 24 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 1 | vaini
# Processing Record 26 of Set 1 | inirida
# Processing Record 27 of Set 1 | grindavik
# Processing Record 28 of Set 1 | busselton
# Processing Record 29 of Set 1 | faanui
# Processing Record 30 of Set 1 | erenhot
# Processing Record 31 of Set 1 | falealupo
# City not found. Skipping...
# Processing Record 32 of Set 1 | boguchany
# Processing Record 33 of Set 1 | upernavik
# Processing Record 34 of Set 1 | cidreira
# Processing Record 35 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 36 of Set 1 | norman wells
# Processing Record 37 of Set 1 | geraldton
# Processing Record 38 of Set 1 | kapaa
# Processing Record 39 of Set 1 | cayenne
# Processing Record 40 of Set 1 | dalbandin
# Processing Record 41 of Set 1 | albany
# Processing Record 42 of Set 1 | sabzevar
# Processing Record 43 of Set 1 | saint anthony
# Processing Record 44 of Set 1 | barrow
# Processing Record 45 of Set 1 | hovd
# Processing Record 46 of Set 1 | ketchikan
# Processing Record 47 of Set 1 | torbay
# Processing Record 48 of Set 1 | gweta
# Processing Record 49 of Set 1 | jamestown
# Processing Record 50 of Set 1 | hue
# Processing Record 1 of Set 2 | saskylakh
# Processing Record 2 of Set 2 | kaitangata
# Processing Record 3 of Set 2 | arraial do cabo
# Processing Record 4 of Set 2 | khomutovo
# Processing Record 5 of Set 2 | moerai
# Processing Record 6 of Set 2 | broken hill
# Processing Record 7 of Set 2 | kikwit
# Processing Record 8 of Set 2 | san-pedro
# Processing Record 9 of Set 2 | bambous virieux
# Processing Record 10 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 11 of Set 2 | hobart
# Processing Record 12 of Set 2 | hithadhoo
# Processing Record 13 of Set 2 | cherskiy
# Processing Record 14 of Set 2 | severo-kurilsk
# Processing Record 15 of Set 2 | aklavik
# Processing Record 16 of Set 2 | dejen
# Processing Record 17 of Set 2 | natal
# Processing Record 18 of Set 2 | puerto ayora
# Processing Record 19 of Set 2 | hasaki
# Processing Record 20 of Set 2 | rafaela
# Processing Record 21 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 22 of Set 2 | nikolskoye
# Processing Record 23 of Set 2 | cape town
# Processing Record 24 of Set 2 | edremit
# Processing Record 25 of Set 2 | taloqan
# Processing Record 26 of Set 2 | winneba
# Processing Record 27 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 28 of Set 2 | gardez
# Processing Record 29 of Set 2 | hilo
# Processing Record 30 of Set 2 | gairatganj
# Processing Record 31 of Set 2 | capaci
# Processing Record 32 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 33 of Set 2 | bethel
# Processing Record 34 of Set 2 | nanortalik
# Processing Record 35 of Set 2 | sinnamary
# Processing Record 36 of Set 2 | ust-maya
# Processing Record 37 of Set 2 | villavicencio
# Processing Record 38 of Set 2 | worland
# Processing Record 39 of Set 2 | khon buri
# Processing Record 40 of Set 2 | touros
# Processing Record 41 of Set 2 | provideniya
# Processing Record 42 of Set 2 | nioro
# Processing Record 43 of Set 2 | new norfolk
# Processing Record 44 of Set 2 | dikson
# Processing Record 45 of Set 2 | castro
# Processing Record 46 of Set 2 | east london
# Processing Record 47 of Set 2 | tasiilaq
# Processing Record 48 of Set 2 | carutapera
# Processing Record 49 of Set 2 | ilulissat
# Processing Record 50 of Set 2 | muzambinho
# Processing Record 1 of Set 3 | karratha
# Processing Record 2 of Set 3 | mahebourg
# Processing Record 3 of Set 3 | hindaun
# Processing Record 4 of Set 3 | kaeo
# Processing Record 5 of Set 3 | correntina
# Processing Record 6 of Set 3 | marsh harbour
# Processing Record 7 of Set 3 | cadillac
# Processing Record 8 of Set 3 | naushahro firoz
# Processing Record 9 of Set 3 | atuona
# Processing Record 10 of Set 3 | georgetown
# Processing Record 11 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 12 of Set 3 | kodiak
# Processing Record 13 of Set 3 | walvis bay
# Processing Record 14 of Set 3 | maarianhamina
# Processing Record 15 of Set 3 | trairi
# Processing Record 16 of Set 3 | montlucon
# Processing Record 17 of Set 3 | norton
# Processing Record 18 of Set 3 | jiexiu
# Processing Record 19 of Set 3 | lazaro cardenas
# Processing Record 20 of Set 3 | cayambe
# Processing Record 21 of Set 3 | alofi
# Processing Record 22 of Set 3 | alotau
# City not found. Skipping...
# Processing Record 23 of Set 3 | svetlogorsk
# Processing Record 24 of Set 3 | moranbah
# Processing Record 25 of Set 3 | airai
# Processing Record 26 of Set 3 | antsohihy
# Processing Record 27 of Set 3 | kingsland
# Processing Record 28 of Set 3 | macau
# Processing Record 29 of Set 3 | auki
# Processing Record 30 of Set 3 | guerrero negro
# Processing Record 31 of Set 3 | egvekinot
# Processing Record 32 of Set 3 | bella union
# Processing Record 33 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 34 of Set 3 | sibu
# Processing Record 35 of Set 3 | victoria
# Processing Record 36 of Set 3 | bagotville
# Processing Record 37 of Set 3 | sussex
# Processing Record 38 of Set 3 | klaksvik
# Processing Record 39 of Set 3 | amga
# Processing Record 40 of Set 3 | saqqez
# Processing Record 41 of Set 3 | port alfred
# Processing Record 42 of Set 3 | buraydah
# Processing Record 43 of Set 3 | sindor
# Processing Record 44 of Set 3 | pudozh
# Processing Record 45 of Set 3 | zaozerne
# Processing Record 46 of Set 3 | fort nelson
# Processing Record 47 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 48 of Set 3 | avarua
# Processing Record 49 of Set 3 | salalah
# Processing Record 50 of Set 3 | luderitz
# Processing Record 1 of Set 4 | khatanga
# Processing Record 2 of Set 4 | kruisfontein
# Processing Record 3 of Set 4 | port elizabeth
# Processing Record 4 of Set 4 | portland
# Processing Record 5 of Set 4 | bac lieu
# Processing Record 6 of Set 4 | harper
# Processing Record 7 of Set 4 | lima
# Processing Record 8 of Set 4 | butaritari
# Processing Record 9 of Set 4 | dobryanka
# Processing Record 10 of Set 4 | matay
# Processing Record 11 of Set 4 | muzhi
# Processing Record 12 of Set 4 | damghan
# Processing Record 13 of Set 4 | beringovskiy
# Processing Record 14 of Set 4 | ostrovnoy
# Processing Record 15 of Set 4 | mayya
# Processing Record 16 of Set 4 | askiz
# Processing Record 17 of Set 4 | leshukonskoye
# Processing Record 18 of Set 4 | rakiv lis
# Processing Record 19 of Set 4 | san carlos de bariloche
# Processing Record 20 of Set 4 | tottori
# Processing Record 21 of Set 4 | kainantu
# Processing Record 22 of Set 4 | erdenet
# Processing Record 23 of Set 4 | thompson
# Processing Record 24 of Set 4 | czarnkow
# Processing Record 25 of Set 4 | clyde river
# Processing Record 26 of Set 4 | eydhafushi
# Processing Record 27 of Set 4 | naze
# Processing Record 28 of Set 4 | awbari
# Processing Record 29 of Set 4 | coquimbo
# Processing Record 30 of Set 4 | dingle
# Processing Record 31 of Set 4 | elizabeth city
# Processing Record 32 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 33 of Set 4 | mount gambier
# Processing Record 34 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 35 of Set 4 | ranong
# Processing Record 36 of Set 4 | yamada
# Processing Record 37 of Set 4 | ler
# Processing Record 38 of Set 4 | talgar
# Processing Record 39 of Set 4 | faya
# Processing Record 40 of Set 4 | vao
# Processing Record 41 of Set 4 | quelimane
# Processing Record 42 of Set 4 | ibra
# Processing Record 43 of Set 4 | clarence town
# Processing Record 44 of Set 4 | jumla
# Processing Record 45 of Set 4 | polovinnoye
# Processing Record 46 of Set 4 | bairiki
# Processing Record 47 of Set 4 | udachnyy
# Processing Record 48 of Set 4 | zhengjiatun
# Processing Record 49 of Set 4 | sirfa
# City not found. Skipping...
# Processing Record 50 of Set 4 | tuktoyaktuk
# Processing Record 1 of Set 5 | ribeira grande
# Processing Record 2 of Set 5 | bandarbeyla
# Processing Record 3 of Set 5 | punta arenas
# Processing Record 4 of Set 5 | lure
# Processing Record 5 of Set 5 | biu
# Processing Record 6 of Set 5 | alvinopolis
# Processing Record 7 of Set 5 | gunnedah
# Processing Record 8 of Set 5 | atambua
# Processing Record 9 of Set 5 | vila franca do campo
# Processing Record 10 of Set 5 | paamiut
# Processing Record 11 of Set 5 | yunjinghong
# City not found. Skipping...
# Processing Record 12 of Set 5 | ixtapa
# Processing Record 13 of Set 5 | iqaluit
# Processing Record 14 of Set 5 | derzhavinsk
# Processing Record 15 of Set 5 | surt
# Processing Record 16 of Set 5 | asfi
# Processing Record 17 of Set 5 | wagar
# Processing Record 18 of Set 5 | van
# Processing Record 19 of Set 5 | port lincoln
# Processing Record 20 of Set 5 | muros
# Processing Record 21 of Set 5 | talnakh
# Processing Record 22 of Set 5 | oyama
# Processing Record 23 of Set 5 | kribi
# Processing Record 24 of Set 5 | abu samrah
# Processing Record 25 of Set 5 | urumqi
# Processing Record 26 of Set 5 | asau
# Processing Record 27 of Set 5 | yulara
# Processing Record 28 of Set 5 | les cayes
# Processing Record 29 of Set 5 | dori
# Processing Record 30 of Set 5 | tabuk
# Processing Record 31 of Set 5 | okhotsk
# Processing Record 32 of Set 5 | bintulu
# Processing Record 33 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 34 of Set 5 | broome
# Processing Record 35 of Set 5 | qaanaaq
# Processing Record 36 of Set 5 | mar del plata
# Processing Record 37 of Set 5 | dujuma
# City not found. Skipping...
# Processing Record 38 of Set 5 | lorengau
# Processing Record 39 of Set 5 | khasan
# Processing Record 40 of Set 5 | marawi
# Processing Record 41 of Set 5 | saint george
# Processing Record 42 of Set 5 | nevelsk
# Processing Record 43 of Set 5 | pedernales
# Processing Record 44 of Set 5 | kavieng
# Processing Record 45 of Set 5 | cabedelo
# Processing Record 46 of Set 5 | kezmarok
# Processing Record 47 of Set 5 | karatau
# Processing Record 48 of Set 5 | xucheng
# Processing Record 49 of Set 5 | alihe
# Processing Record 50 of Set 5 | la palma
# Processing Record 1 of Set 6 | hambantota
# Processing Record 2 of Set 6 | mogwase
# Processing Record 3 of Set 6 | zamosc
# Processing Record 4 of Set 6 | te anau
# Processing Record 5 of Set 6 | berlevag
# Processing Record 6 of Set 6 | huarmey
# Processing Record 7 of Set 6 | lebu
# Processing Record 8 of Set 6 | bredasdorp
# Processing Record 9 of Set 6 | prince rupert
# Processing Record 10 of Set 6 | ambon
# Processing Record 11 of Set 6 | alta floresta
# Processing Record 12 of Set 6 | genhe
# Processing Record 13 of Set 6 | sisimiut
# Processing Record 14 of Set 6 | corinth
# Processing Record 15 of Set 6 | itoman
# Processing Record 16 of Set 6 | hofn
# Processing Record 17 of Set 6 | guia de isora
# Processing Record 18 of Set 6 | lingyuan
# Processing Record 19 of Set 6 | sitka
# Processing Record 20 of Set 6 | kracheh
# City not found. Skipping...
# Processing Record 21 of Set 6 | celendin
# Processing Record 22 of Set 6 | salinas
# Processing Record 23 of Set 6 | terrace bay
# Processing Record 24 of Set 6 | acapulco
# Processing Record 25 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 26 of Set 6 | mopipi
# Processing Record 27 of Set 6 | koilas
# Processing Record 28 of Set 6 | lahij
# Processing Record 29 of Set 6 | vagur
# Processing Record 30 of Set 6 | canchungo
# Processing Record 31 of Set 6 | general roca
# Processing Record 32 of Set 6 | shelburne
# Processing Record 33 of Set 6 | jiayuguan
# Processing Record 34 of Set 6 | la ronge
# Processing Record 35 of Set 6 | chokurdakh
# Processing Record 36 of Set 6 | henties bay
# Processing Record 37 of Set 6 | saint-augustin
# Processing Record 38 of Set 6 | puerto cabezas
# Processing Record 39 of Set 6 | marystown
# Processing Record 40 of Set 6 | port hawkesbury
# Processing Record 41 of Set 6 | laguna
# Processing Record 42 of Set 6 | lagoa
# Processing Record 43 of Set 6 | teahupoo
# Processing Record 44 of Set 6 | sankt johann im pongau
# Processing Record 45 of Set 6 | kiomboi
# Processing Record 46 of Set 6 | moba
# Processing Record 47 of Set 6 | izumo
# Processing Record 48 of Set 6 | central point
# Processing Record 49 of Set 6 | zverinogolovskoye
# Processing Record 50 of Set 6 | bluffton
# Processing Record 1 of Set 7 | belyy yar
# Processing Record 2 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 3 of Set 7 | ancud
# Processing Record 4 of Set 7 | yellowknife
# Processing Record 5 of Set 7 | bilibino
# Processing Record 6 of Set 7 | clearwater
# Processing Record 7 of Set 7 | copiapo
# Processing Record 8 of Set 7 | orlik
# Processing Record 9 of Set 7 | san quintin
# Processing Record 10 of Set 7 | westport
# Processing Record 11 of Set 7 | manggar
# Processing Record 12 of Set 7 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 13 of Set 7 | thinadhoo
# Processing Record 14 of Set 7 | belaya gora
# Processing Record 15 of Set 7 | porbandar
# Processing Record 16 of Set 7 | sakakah
# Processing Record 17 of Set 7 | leeton
# Processing Record 18 of Set 7 | labuhan
# Processing Record 19 of Set 7 | lompoc
# Processing Record 20 of Set 7 | diapaga
# Processing Record 21 of Set 7 | rawannawi
# City not found. Skipping...
# Processing Record 22 of Set 7 | adana
# Processing Record 23 of Set 7 | aykhal
# Processing Record 24 of Set 7 | dicabisagan
# Processing Record 25 of Set 7 | imbituba
# Processing Record 26 of Set 7 | ewo
# Processing Record 27 of Set 7 | coihaique
# Processing Record 28 of Set 7 | tiksi
# Processing Record 29 of Set 7 | pangody
# Processing Record 30 of Set 7 | antofagasta
# Processing Record 31 of Set 7 | flin flon
# Processing Record 32 of Set 7 | dharchula
# Processing Record 33 of Set 7 | san cristobal
# Processing Record 34 of Set 7 | acajutla
# Processing Record 35 of Set 7 | khachrod
# Processing Record 36 of Set 7 | zaysan
# Processing Record 37 of Set 7 | keti bandar
# Processing Record 38 of Set 7 | adrar
# Processing Record 39 of Set 7 | gwadar
# Processing Record 40 of Set 7 | tuatapere
# Processing Record 41 of Set 7 | purpe
# Processing Record 42 of Set 7 | islamkot
# Processing Record 43 of Set 7 | ahipara
# Processing Record 44 of Set 7 | menongue
# Processing Record 45 of Set 7 | ban nahin
# Processing Record 46 of Set 7 | bilma
# Processing Record 47 of Set 7 | tecpan
# Processing Record 48 of Set 7 | helong
# Processing Record 49 of Set 7 | nemuro
# Processing Record 50 of Set 7 | taoudenni
# Processing Record 1 of Set 8 | parakai
# Processing Record 2 of Set 8 | kokopo
# Processing Record 3 of Set 8 | nellikkuppam
# Processing Record 4 of Set 8 | yerbogachen
# Processing Record 5 of Set 8 | lasa
# Processing Record 6 of Set 8 | coalcoman
# City not found. Skipping...
# Processing Record 7 of Set 8 | yeppoon
# Processing Record 8 of Set 8 | tadine
# Processing Record 9 of Set 8 | takhtamygda
# Processing Record 10 of Set 8 | zavoi
# Processing Record 11 of Set 8 | maragogi
# Processing Record 12 of Set 8 | hanstholm
# Processing Record 13 of Set 8 | curuguaty
# Processing Record 14 of Set 8 | chumikan
# Processing Record 15 of Set 8 | quatre cocos
# Processing Record 16 of Set 8 | codrington
# Processing Record 17 of Set 8 | port blair
# Processing Record 18 of Set 8 | tazovskiy
# Processing Record 19 of Set 8 | cabo san lucas
# Processing Record 20 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 21 of Set 8 | tapes
# Processing Record 22 of Set 8 | lagos
# Processing Record 23 of Set 8 | katsuura
# Processing Record 24 of Set 8 | souillac
# Processing Record 25 of Set 8 | samarai
# Processing Record 26 of Set 8 | jiaozuo
# Processing Record 27 of Set 8 | anchorage
# Processing Record 28 of Set 8 | havre-saint-pierre
# Processing Record 29 of Set 8 | los llanos de aridane
# Processing Record 30 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 31 of Set 8 | deputatskiy
# Processing Record 32 of Set 8 | blantyre
# Processing Record 33 of Set 8 | dzerzhinskoye
# Processing Record 34 of Set 8 | sabang
# Processing Record 35 of Set 8 | tessalit
# Processing Record 36 of Set 8 | qinzhou
# Processing Record 37 of Set 8 | dunedin
# Processing Record 38 of Set 8 | na wa
# Processing Record 39 of Set 8 | kodinsk
# Processing Record 40 of Set 8 | fortuna
# Processing Record 41 of Set 8 | barmer
# Processing Record 42 of Set 8 | high rock
# Processing Record 43 of Set 8 | bressuire
# Processing Record 44 of Set 8 | columbus
# Processing Record 45 of Set 8 | namatanai
# Processing Record 46 of Set 8 | basseterre
# Processing Record 47 of Set 8 | vigrestad
# Processing Record 48 of Set 8 | brownsville
# Processing Record 49 of Set 8 | kasongo-lunda
# Processing Record 50 of Set 8 | rio grande
# Processing Record 1 of Set 9 | zeya
# Processing Record 2 of Set 9 | kavaratti
# Processing Record 3 of Set 9 | hami
# Processing Record 4 of Set 9 | progreso
# Processing Record 5 of Set 9 | goderich
# Processing Record 6 of Set 9 | carnarvon
# Processing Record 7 of Set 9 | umm durman
# City not found. Skipping...
# Processing Record 8 of Set 9 | chortomlyk
# Processing Record 9 of Set 9 | meulaboh
# Processing Record 10 of Set 9 | juigalpa
# Processing Record 11 of Set 9 | tura
# Processing Record 12 of Set 9 | ozinki
# Processing Record 13 of Set 9 | narsaq
# Processing Record 14 of Set 9 | qitaihe
# Processing Record 15 of Set 9 | bay roberts
# Processing Record 16 of Set 9 | san patricio
# Processing Record 17 of Set 9 | razdolnoye
# Processing Record 18 of Set 9 | seymchan
# Processing Record 19 of Set 9 | mangrol
# Processing Record 20 of Set 9 | cap malheureux
# Processing Record 21 of Set 9 | shimoda
# Processing Record 22 of Set 9 | nuuk
# Processing Record 23 of Set 9 | pevek
# Processing Record 24 of Set 9 | petropavl
# Processing Record 25 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 26 of Set 9 | zaokskiy
# Processing Record 27 of Set 9 | rabo de peixe
# Processing Record 28 of Set 9 | balkhash
# Processing Record 29 of Set 9 | ardistan
# City not found. Skipping...
# Processing Record 30 of Set 9 | gizo
# Processing Record 31 of Set 9 | oistins
# Processing Record 32 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 33 of Set 9 | pacific grove
# Processing Record 34 of Set 9 | vincennes
# Processing Record 35 of Set 9 | stromness
# Processing Record 36 of Set 9 | nsanje
# Processing Record 37 of Set 9 | ayacucho
# Processing Record 38 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 39 of Set 9 | sao joao da barra
# Processing Record 40 of Set 9 | ahuimanu
# Processing Record 41 of Set 9 | jiazi
# Processing Record 42 of Set 9 | golesti
# Processing Record 43 of Set 9 | hurghada
# Processing Record 44 of Set 9 | daoukro
# Processing Record 45 of Set 9 | itarema
# Processing Record 46 of Set 9 | jalu
# Processing Record 47 of Set 9 | samagaltay
# Processing Record 48 of Set 9 | nzerekore
# Processing Record 49 of Set 9 | monterrey
# Processing Record 50 of Set 9 | obidos
# Processing Record 1 of Set 10 | isla vista
# Processing Record 2 of Set 10 | tawang
# Processing Record 3 of Set 10 | lixourion
# Processing Record 4 of Set 10 | pochutla
# Processing Record 5 of Set 10 | camocim
# Processing Record 6 of Set 10 | shubarshi
# Processing Record 7 of Set 10 | cockburn town
# Processing Record 8 of Set 10 | saint-denis
# Processing Record 9 of Set 10 | genoa
# Processing Record 10 of Set 10 | the valley
# Processing Record 11 of Set 10 | tiarei
# Processing Record 12 of Set 10 | dubai
# Processing Record 13 of Set 10 | hervey bay
# Processing Record 14 of Set 10 | tual
# Processing Record 15 of Set 10 | buala
# Processing Record 16 of Set 10 | vanimo
# Processing Record 17 of Set 10 | zacatecas
# Processing Record 18 of Set 10 | katherine
# Processing Record 19 of Set 10 | krasnoselkup
# Processing Record 20 of Set 10 | kungurtug
# Processing Record 21 of Set 10 | rancho palos verdes
# Processing Record 22 of Set 10 | sumbawanga
# Processing Record 23 of Set 10 | vestmannaeyjar
# Processing Record 24 of Set 10 | nizhneudinsk
# Processing Record 25 of Set 10 | panaba
# Processing Record 26 of Set 10 | praia da vitoria
# Processing Record 27 of Set 10 | log
# Processing Record 28 of Set 10 | muncar
# Processing Record 29 of Set 10 | lorca
# Processing Record 30 of Set 10 | dwarka
# Processing Record 31 of Set 10 | luebo
# Processing Record 32 of Set 10 | boshnyakovo
# Processing Record 33 of Set 10 | thessalon
# Processing Record 34 of Set 10 | kawalu
# Processing Record 35 of Set 10 | itarare
# Processing Record 36 of Set 10 | abu dhabi
# Processing Record 37 of Set 10 | kahului
# Processing Record 38 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 39 of Set 10 | tondano
# Processing Record 40 of Set 10 | tabialan
# City not found. Skipping...
# Processing Record 41 of Set 10 | tautira
# Processing Record 42 of Set 10 | puquio
# Processing Record 43 of Set 10 | mattru
# Processing Record 44 of Set 10 | beyneu
# Processing Record 45 of Set 10 | piacabucu
# Processing Record 46 of Set 10 | vardo
# Processing Record 47 of Set 10 | pokhara
# Processing Record 48 of Set 10 | burnie
# Processing Record 49 of Set 10 | nova soure
# Processing Record 50 of Set 10 | ye
# City not found. Skipping...
# Processing Record 1 of Set 11 | urdzhar
# City not found. Skipping...
# Processing Record 2 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 3 of Set 11 | constantine
# Processing Record 4 of Set 11 | novopokrovka
# Processing Record 5 of Set 11 | wawa
# Processing Record 6 of Set 11 | emba
# Processing Record 7 of Set 11 | flinders
# Processing Record 8 of Set 11 | kontagora
# Processing Record 9 of Set 11 | bloemfontein
# Processing Record 10 of Set 11 | surskoye
# Processing Record 11 of Set 11 | west bay
# Processing Record 12 of Set 11 | padang
# Processing Record 13 of Set 11 | anloga
# Processing Record 14 of Set 11 | caravelas
# Processing Record 15 of Set 11 | konevo
# Processing Record 16 of Set 11 | sibolga
# Processing Record 17 of Set 11 | aleysk
# Processing Record 18 of Set 11 | pauini
# Processing Record 19 of Set 11 | kismayo
# Processing Record 20 of Set 11 | santa flavia
# Processing Record 21 of Set 11 | pangnirtung
# Processing Record 22 of Set 11 | schwerin
# Processing Record 23 of Set 11 | chuy
# Processing Record 24 of Set 11 | mount isa
# Processing Record 25 of Set 11 | zhezkazgan
# Processing Record 26 of Set 11 | clarksburg
# Processing Record 27 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 28 of Set 11 | yenagoa
# Processing Record 29 of Set 11 | alice springs
# Processing Record 30 of Set 11 | canutama
# Processing Record 31 of Set 11 | haikou
# Processing Record 32 of Set 11 | phan rang
# City not found. Skipping...
# Processing Record 33 of Set 11 | tarakan
# Processing Record 34 of Set 11 | pasuruan
# Processing Record 35 of Set 11 | kununurra
# Processing Record 36 of Set 11 | nome
# Processing Record 37 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 38 of Set 11 | carikar
# City not found. Skipping...
# Processing Record 39 of Set 11 | kermanshah
# Processing Record 40 of Set 11 | constitucion
# Processing Record 41 of Set 11 | nieves
# Processing Record 42 of Set 11 | ramnicu sarat
# Processing Record 43 of Set 11 | abay
# Processing Record 44 of Set 11 | zambezi
# Processing Record 45 of Set 11 | hualmay
# Processing Record 46 of Set 11 | karakendzha
# City not found. Skipping...
# Processing Record 47 of Set 11 | pirapora
# Processing Record 48 of Set 11 | husavik
# Processing Record 49 of Set 11 | san javier
# Processing Record 50 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 1 of Set 12 | prenzlau
# Processing Record 2 of Set 12 | ewa beach
# Processing Record 3 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 4 of Set 12 | olinda
# Processing Record 5 of Set 12 | labytnangi
# Processing Record 6 of Set 12 | sioux lookout
# Processing Record 7 of Set 12 | la grande
# Processing Record 8 of Set 12 | milkovo
# Processing Record 9 of Set 12 | hailar
# Processing Record 10 of Set 12 | hammerfest
# Processing Record 11 of Set 12 | bima
# Processing Record 12 of Set 12 | bria
# Processing Record 13 of Set 12 | istok
# Processing Record 14 of Set 12 | poum
# Processing Record 15 of Set 12 | bubaque
# Processing Record 16 of Set 12 | iracoubo
# Processing Record 17 of Set 12 | biloela
# Processing Record 18 of Set 12 | vazante
# Processing Record 19 of Set 12 | comodoro rivadavia
# Processing Record 20 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 21 of Set 12 | slavyanka
# Processing Record 22 of Set 12 | grdelica
# Processing Record 23 of Set 12 | noumea
# Processing Record 24 of Set 12 | fairbanks
# Processing Record 25 of Set 12 | bardiyah
# Processing Record 26 of Set 12 | dovbysh
# Processing Record 27 of Set 12 | maonon
# Processing Record 28 of Set 12 | alyangula
# Processing Record 29 of Set 12 | agadir
# Processing Record 30 of Set 12 | valdivia
# Processing Record 31 of Set 12 | kant
# Processing Record 32 of Set 12 | puerto ayacucho
# Processing Record 33 of Set 12 | maymanak
# City not found. Skipping...
# Processing Record 34 of Set 12 | ca mau
# Processing Record 35 of Set 12 | farah
# Processing Record 36 of Set 12 | brae
# Processing Record 37 of Set 12 | same
# Processing Record 38 of Set 12 | namibe
# Processing Record 39 of Set 12 | bosaso
# Processing Record 40 of Set 12 | nyrob
# Processing Record 41 of Set 12 | dombarovskiy
# Processing Record 42 of Set 12 | saint-pierre
# Processing Record 43 of Set 12 | lavrentiya
# Processing Record 44 of Set 12 | longlac
# City not found. Skipping...
# Processing Record 45 of Set 12 | karasburg
# Processing Record 46 of Set 12 | soc trang
# Processing Record 47 of Set 12 | oakland
# Processing Record 48 of Set 12 | kindu
# Processing Record 49 of Set 12 | redlands
# Processing Record 50 of Set 12 | yingkou
# Processing Record 1 of Set 13 | pau brasil
# Processing Record 2 of Set 13 | tangjiazhuang
# Processing Record 3 of Set 13 | lata
# Processing Record 4 of Set 13 | douglas
# Processing Record 5 of Set 13 | naushki
# Processing Record 6 of Set 13 | mahbubabad
# Processing Record 7 of Set 13 | ucluelet
# Processing Record 8 of Set 13 | mana
# Processing Record 9 of Set 13 | puerto escondido
# Processing Record 10 of Set 13 | bagula
# Processing Record 11 of Set 13 | nantucket
# Processing Record 12 of Set 13 | eyrarbakki
# Processing Record 13 of Set 13 | andujar
# Processing Record 14 of Set 13 | saint-francois
# Processing Record 15 of Set 13 | kangaatsiaq
# Processing Record 16 of Set 13 | benjamin constant
# Processing Record 17 of Set 13 | uyuni
# Processing Record 18 of Set 13 | suntar
# Processing Record 19 of Set 13 | dugna
# City not found. Skipping...
# Processing Record 20 of Set 13 | bikaner
# Processing Record 21 of Set 13 | rambha
# Processing Record 22 of Set 13 | boende
# Processing Record 23 of Set 13 | makakilo city
# Processing Record 24 of Set 13 | rudnogorsk
# Processing Record 25 of Set 13 | motupe
# Processing Record 26 of Set 13 | aksu
# Processing Record 27 of Set 13 | sondrio
# Processing Record 28 of Set 13 | lahat
# Processing Record 29 of Set 13 | gamba
# Processing Record 30 of Set 13 | crawfordsville
# Processing Record 31 of Set 13 | leningradskiy
# Processing Record 32 of Set 13 | road town
# Processing Record 33 of Set 13 | lazo
# Processing Record 34 of Set 13 | aitape
# Processing Record 35 of Set 13 | malanje
# Processing Record 36 of Set 13 | piploda
# Processing Record 37 of Set 13 | kalashnikovo
# Processing Record 38 of Set 13 | paso de carrasco
# Processing Record 39 of Set 13 | aswan
# Processing Record 40 of Set 13 | san pedro
# Processing Record 41 of Set 13 | wad madani
# Processing Record 42 of Set 13 | nishihara
# Processing Record 43 of Set 13 | labrea
# Processing Record 44 of Set 13 | benguela
# Processing Record 45 of Set 13 | ylivieska
# Processing Record 46 of Set 13 | srednekolymsk
# Processing Record 47 of Set 13 | vanavara
# Processing Record 48 of Set 13 | matagami
# Processing Record 49 of Set 13 | alekseyevka
# Processing Record 50 of Set 13 | alexandria
# Processing Record 1 of Set 14 | yuanping
# Processing Record 2 of Set 14 | waipawa
# Processing Record 3 of Set 14 | xudat
# Processing Record 4 of Set 14 | redcar
# Processing Record 5 of Set 14 | palmer
# Processing Record 6 of Set 14 | qandala
# Processing Record 7 of Set 14 | kadyy
# Processing Record 8 of Set 14 | plettenberg bay
# Processing Record 9 of Set 14 | ekibastuz
# Processing Record 10 of Set 14 | turhal
# Processing Record 11 of Set 14 | sao raimundo das mangabeiras
# Processing Record 12 of Set 14 | solnechnyy
# Processing Record 13 of Set 14 | mountain home
# Processing Record 14 of Set 14 | hanna
# Processing Record 15 of Set 14 | sirjan
# Processing Record 16 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 17 of Set 14 | podbelsk
# City not found. Skipping...
# Processing Record 18 of Set 14 | richards bay
# Processing Record 19 of Set 14 | mahon
# Processing Record 20 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 21 of Set 14 | baghmara
# Processing Record 22 of Set 14 | korla
# Processing Record 23 of Set 14 | aripuana
# Processing Record 24 of Set 14 | baykit
# Processing Record 25 of Set 14 | espirito santo do pinhal
# Processing Record 26 of Set 14 | vryburg
# Processing Record 27 of Set 14 | pangai
# Processing Record 28 of Set 14 | keuruu
# Processing Record 29 of Set 14 | donskoye
# Processing Record 30 of Set 14 | garissa
# Processing Record 31 of Set 14 | bacolod
# Processing Record 32 of Set 14 | batagay-alyta
# Processing Record 33 of Set 14 | southbridge
# Processing Record 34 of Set 14 | trelew
# Processing Record 35 of Set 14 | hrodna
# Processing Record 36 of Set 14 | great falls
# Processing Record 37 of Set 14 | svetlaya
# Processing Record 38 of Set 14 | pandhana
# Processing Record 39 of Set 14 | naval
# Processing Record 40 of Set 14 | masuda
# Processing Record 41 of Set 14 | winslow
# Processing Record 42 of Set 14 | baturinskaya
# Processing Record 43 of Set 14 | vila
# Processing Record 44 of Set 14 | puerto castilla
# Processing Record 45 of Set 14 | north bend
# Processing Record 46 of Set 14 | druzhba
# Processing Record 47 of Set 14 | college
# Processing Record 48 of Set 14 | marienburg
# Processing Record 49 of Set 14 | japura
# Processing Record 50 of Set 14 | kloulklubed
# Processing Record 1 of Set 15 | champerico
# Processing Record 2 of Set 15 | west fargo
# Processing Record 3 of Set 15 | solovetskiy
# City not found. Skipping...
# Processing Record 4 of Set 15 | mayaposi
# City not found. Skipping...
# Processing Record 5 of Set 15 | saravan
# Processing Record 6 of Set 15 | poso
# Processing Record 7 of Set 15 | emmett
# Processing Record 8 of Set 15 | manta
# Processing Record 9 of Set 15 | nouadhibou
# Processing Record 10 of Set 15 | binghamton
# Processing Record 11 of Set 15 | wahran
# City not found. Skipping...
# Processing Record 12 of Set 15 | honiara
# Processing Record 13 of Set 15 | yavaros
# Processing Record 14 of Set 15 | smithers
# Processing Record 15 of Set 15 | bergen
# Processing Record 16 of Set 15 | jurm
# Processing Record 17 of Set 15 | maniitsoq
# Processing Record 18 of Set 15 | yeniseysk
# Processing Record 19 of Set 15 | zachagansk
# City not found. Skipping...
# Processing Record 20 of Set 15 | lacey
# Processing Record 21 of Set 15 | evensk
# Processing Record 22 of Set 15 | knyaze-volkonskoye
# Processing Record 23 of Set 15 | cuiluan
# Processing Record 24 of Set 15 | newtonmore
# Processing Record 25 of Set 15 | amuntai
# Processing Record 26 of Set 15 | bianzhuang
# Processing Record 27 of Set 15 | arroyo
# Processing Record 28 of Set 15 | anadyr
# Processing Record 29 of Set 15 | tidore
# City not found. Skipping...
# Processing Record 30 of Set 15 | port hedland
# Processing Record 31 of Set 15 | yinchuan
# Processing Record 32 of Set 15 | manavalakurichi
# Processing Record 33 of Set 15 | ketchenery
# City not found. Skipping...
# Processing Record 34 of Set 15 | isangel
# Processing Record 35 of Set 15 | nortelandia
# Processing Record 36 of Set 15 | aleksandrov gay
# Processing Record 37 of Set 15 | darhan
# Processing Record 38 of Set 15 | buenos aires
# Processing Record 39 of Set 15 | barra patuca
# Processing Record 40 of Set 15 | severobaykalsk
# Processing Record 41 of Set 15 | bull savanna
# Processing Record 42 of Set 15 | silvassa
# Processing Record 43 of Set 15 | mindelo
# Processing Record 44 of Set 15 | mehamn
# Processing Record 45 of Set 15 | mizdah
# Processing Record 46 of Set 15 | huaral
# Processing Record 47 of Set 15 | linshu
# City not found. Skipping...
# Processing Record 48 of Set 15 | beloha
# Processing Record 49 of Set 15 | russell
# Processing Record 50 of Set 15 | vredendal
# Processing Record 1 of Set 16 | vienenburg
# Processing Record 2 of Set 16 | campbell river
# Processing Record 3 of Set 16 | ratangarh
# Processing Record 4 of Set 16 | zyryanka
# Processing Record 5 of Set 16 | kandrian
# Processing Record 6 of Set 16 | senador jose porfirio
# Processing Record 7 of Set 16 | scalloway
# City not found. Skipping...
# Processing Record 8 of Set 16 | ulladulla
# Processing Record 9 of Set 16 | akdepe
# Processing Record 10 of Set 16 | saldanha
# Processing Record 11 of Set 16 | puerto colombia
# Processing Record 12 of Set 16 | smidovich
# Processing Record 13 of Set 16 | soavinandriana
# Processing Record 14 of Set 16 | chagda
# City not found. Skipping...
# Processing Record 15 of Set 16 | linxia
# Processing Record 16 of Set 16 | mbandaka
# Processing Record 17 of Set 16 | boca do acre
# Processing Record 18 of Set 16 | eyemouth
# Processing Record 19 of Set 16 | aiquile
# Processing Record 20 of Set 16 | balabac
# Processing Record 21 of Set 16 | keroka
# Processing Record 22 of Set 16 | valleyview
# Processing Record 23 of Set 16 | kurilsk
# Processing Record 24 of Set 16 | san vicente
# Processing Record 25 of Set 16 | ossora
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Oksfjord  70.2396   22.3479     46.47        79          97        5.19
# 1        Olot  42.1810    2.4901     76.80        56           0        2.53
# 2  Sao Filipe  14.8961  -24.4956     77.14        84          96        3.38
# 3    Hermanus -34.4187   19.2345     55.90        77          13        8.10
# 4     Rikitea -23.1203 -134.9692     74.73        75           0       11.79
# 5      Viedma -40.8135  -62.9967     61.68        25          94       15.73
# 6     Ushuaia -54.8000  -68.3000     46.06        66          40        9.22
# 7     Kitimat  54.0524 -128.6534     65.91        69          30        5.01
# 8      Fuling  29.7022  107.3919     73.27        88          91        3.11
# 9    Hamilton  39.1834  -84.5333     76.91        71          90        1.99
#
#   Country Current Description
# 0      NO     overcast clouds
# 1      ES           clear sky
# 2      CV     overcast clouds
# 3      ZA          few clouds
# 4      PF           clear sky
# 5      AR     overcast clouds
# 6      AR    scattered clouds
# 7      CA    scattered clouds
# 8      CN     overcast clouds
# 9      US     overcast clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Oksfjord      NO  70.2396   22.3479     46.47        79          97
# 1        Olot      ES  42.1810    2.4901     76.80        56           0
# 2  Sao Filipe      CV  14.8961  -24.4956     77.14        84          96
# 3    Hermanus      ZA -34.4187   19.2345     55.90        77          13
# 4     Rikitea      PF -23.1203 -134.9692     74.73        75           0
# 5      Viedma      AR -40.8135  -62.9967     61.68        25          94
# 6     Ushuaia      AR -54.8000  -68.3000     46.06        66          40
# 7     Kitimat      CA  54.0524 -128.6534     65.91        69          30
# 8      Fuling      CN  29.7022  107.3919     73.27        88          91
# 9    Hamilton      US  39.1834  -84.5333     76.91        71          90
#
#   Current Description
# 0     overcast clouds
# 1           clear sky
# 2     overcast clouds
# 3          few clouds
# 4           clear sky
# 5     overcast clouds
# 6    scattered clouds
# 7    scattered clouds
# 8     overcast clouds
# 9     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "weather_data/Weatherpy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="Weatherpy_database")
